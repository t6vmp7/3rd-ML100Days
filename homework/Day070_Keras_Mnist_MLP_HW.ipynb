# %% [markdown]
# # 作業目標:¶
# 利用手寫辨識資料說明MLP 中, 神經網路層的多寡跟預測結果的差異

# %% [markdown]
# # 作業重點:
# [練習]請嘗試新增一層或兩層看看最後預測結果是否有差異
# model.add(Dense(units=256, input_dim=784, kernel_initializer='normal', activation='relu'))

# %% [markdown]
# # 資料預處理

# %%
from keras.utils import np_utils
import numpy as np
np.random.seed(10)
# Out:
# Using TensorFlow backend.

# %%
#載入手寫辨識的資料集
from keras.datasets import mnist
(x_train_image,y_train_label),\
(x_test_image,y_test_label)= mnist.load_data()

# %%
#指定測試集與訓練資料集
x_Train =x_train_image.reshape(60000, 784).astype('float32')
x_Test = x_test_image.reshape(10000, 784).astype('float32')

# %%
# normalize inputs from 0-255 to 0-1
x_Train_normalize = x_Train / 255
x_Test_normalize = x_Test / 255

# %%
#把LABEL轉成NUMERICAL Categorical 
y_Train_OneHot = np_utils.to_categorical(y_train_label)
y_Test_OneHot = np_utils.to_categorical(y_test_label)

# %% [markdown]
# # 建立模型

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
#建立模型

# %%
model = Sequential()
Dense(units=256, input_dim=784, kernel_initializer='normal', activation='relu')
model.add(Dense(units=256, input_dim=784, kernel_initializer='normal', activation='relu'))
model.add(Dense(units=256, input_dim=784, kernel_initializer='normal', activation='relu'))
model.add(Dense(units=10, kernel_initializer='normal', activation='softmax'))

# %%
print(model.summary())
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_13 (Dense)             (None, 256)               200960
# _________________________________________________________________
# dense_14 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_15 (Dense)             (None, 10)                2570
# =================================================================
# Total params: 269,322
# Trainable params: 269,322
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# # 訓練模型

# %%
model.compile(loss='categorical_crossentropy', 
              optimizer='adam', metrics=['accuracy'])

# %%
train_history =model.fit(x=x_Train_normalize,
                         y=y_Train_OneHot,validation_split=0.2, 
                         epochs=10, batch_size=32,verbose=1)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/10
# 48000/48000 [==============================] - 3s 68us/step - loss: 0.0258 - accuracy: 0.9925 - val_loss: 0.0946 - val_accuracy: 0.9784
# Epoch 2/10
# 48000/48000 [==============================] - 3s 69us/step - loss: 0.0136 - accuracy: 0.9954 - val_loss: 0.1282 - val_accuracy: 0.9743
# Epoch 3/10
# 48000/48000 [==============================] - 3s 67us/step - loss: 0.0170 - accuracy: 0.9943 - val_loss: 0.1345 - val_accuracy: 0.9737
# Epoch 4/10
# 48000/48000 [==============================] - 3s 66us/step - loss: 0.0142 - accuracy: 0.9957 - val_loss: 0.1329 - val_accuracy: 0.9761
# Epoch 5/10
# 48000/48000 [==============================] - 3s 67us/step - loss: 0.0141 - accuracy: 0.9955 - val_loss: 0.1230 - val_accuracy: 0.9798
# Epoch 6/10
# 48000/48000 [==============================] - 3s 67us/step - loss: 0.0120 - accuracy: 0.9962 - val_loss: 0.1386 - val_accuracy: 0.9775
# Epoch 7/10
# 48000/48000 [==============================] - 3s 67us/step - loss: 0.0125 - accuracy: 0.9962 - val_loss: 0.1687 - val_accuracy: 0.9730
# Epoch 8/10
# 48000/48000 [==============================] - 3s 67us/step - loss: 0.0097 - accuracy: 0.9967 - val_loss: 0.1466 - val_accuracy: 0.9779
# Epoch 9/10
# 48000/48000 [==============================] - 3s 67us/step - loss: 0.0134 - accuracy: 0.9964 - val_loss: 0.1571 - val_accuracy: 0.9753
# Epoch 10/10
# 48000/48000 [==============================] - 3s 67us/step - loss: 0.0104 - accuracy: 0.9968 - val_loss: 0.1469 - val_accuracy: 0.9778

# %% [markdown]
# # 以圖形顯示訓練過程

# %%
import matplotlib.pyplot as plt
def show_train_history(train_history,train,validation):
    plt.plot(train_history.history[train])
    plt.plot(train_history.history[validation])
    plt.title('Train History')
    plt.ylabel(train)
    plt.xlabel('Epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()

# %%
train_history.history.keys()
# Out:
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy'])

# %%
show_train_history(train_history,'accuracy','val_accuracy')

# %%
show_train_history(train_history,'loss','val_loss')

# %% [markdown]
# # 評估模型準確率

# %%
scores = model.evaluate(x_Test_normalize, y_Test_OneHot)
print()
print('accuracy=',scores[1])
# Out:
# 10000/10000 [==============================] - 0s 15us/step
#
# accuracy= 0.9807000160217285
